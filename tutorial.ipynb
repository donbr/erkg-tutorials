# %% [markdown]
# ## Load ICIJ dataset

# %%
import spacy
from spacy.tokens import DocBin
from spacy import displacy
import srsly

from spacy_lancedb_linker.kb import AnnKnowledgeBase
from spacy_lancedb_linker.linker import AnnLinker  # noqa
from spacy_lancedb_linker.types import Alias, Entity
from src.scraper import SPACY_MODEL

# %%
scrape_nlp: spacy.Language = spacy.load(SPACY_MODEL)

# %%
doc_bin = DocBin().from_disk(path="data/dataset.spacy")
len(doc_bin)
# Out:
# 2

# %%
docs = list(doc_bin.get_docs(scrape_nlp.vocab))

# %% [markdown]
# ## Load example Wikidata KB (manual input)

# %%
entities = [Entity(**entity) for entity in srsly.read_jsonl("data/icij-example/entities.jsonl")]

# %%
aliases = [Alias(**alias) for alias in srsly.read_jsonl("data/icij-example/aliases.jsonl")] + [
    Alias(alias=entity.name, entities=[entity.entity_id], probabilities=[1]) for entity in entities
]

# %%
uri = "data/sample-lancedb"
ann_kb = AnnKnowledgeBase(uri=uri)
ann_kb.add_entities(entities)
ann_kb.add_aliases(aliases)
# Out:
# /home/donbr/erkg-tutorials/venv/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
ann_linker = scrape_nlp.add_pipe("ann_linker", last=True)
ann_linker.set_kb(ann_kb)

# %%
scrape_nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner',
#  'ann_linker']

# %%
doc = scrape_nlp(docs[0])

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Former
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Czech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  leader’s secret
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     French
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">388148</a>
# </span>
# </mark>
#  estate, revealed in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pandora Papers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , listed for sale.<br>The luxury
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Riviera
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">388148</a>
# </span>
# </mark>
#  property featured in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ICIJ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s investigation into then-Prime Minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andrej Babis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">960146</a>
# </span>
# </mark>
# ’ secret offshore dealings, and is now part of a money laundering probe by
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     French
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">388148</a>
# </span>
# </mark>
#  authorities.<br>Former
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Czech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  prime minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andrej Babis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">960146</a>
# </span>
# </mark>
# .<br>High-end real estate agency
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sotheby’s International Realty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">1551574</a>
# </span>
# </mark>
#  has listed for sale the sprawling
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     French
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">388148</a>
# </span>
# </mark>
#  property of former
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Czech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  prime minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andrej Babis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">960146</a>
# </span>
# </mark>
#  which was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  revealed in
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Pandora Papers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the International Consortium of Investigative Journalists
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .<br>The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $24.7 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  villa, located in the town of
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mougins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , near
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cannes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , was at the center of the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  investigation into the secret offshore dealings of the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Czech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  billionaire-turned-politician, who was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.

# %% [markdown]
# ## Load custom KB built from Senzing results

# %%
import pytextrank
# Out:
# /home/donbr/erkg-tutorials/venv/lib/python3.12/site-packages

# %%
entities = [Entity(**entity) for entity in srsly.read_jsonl("data/senzing/entities.jsonl")]
len(entities)
# Out:
# 29

# %%
aliases = [Alias(**alias) for alias in srsly.read_jsonl("data/senzing/aliases.jsonl")] + [
    Alias(alias=entity.name, entities=[entity.entity_id], probabilities=[1]) for entity in entities
]
len(aliases)
# Out:
# 2502

# %%
uri = "data/sample-lancedb"
ann_kb = AnnKnowledgeBase(uri=uri)
ann_kb.add_entities(entities)
ann_kb.add_aliases(aliases)

# %%
scrape_nlp: spacy.Language = spacy.load(SPACY_MODEL)
ann_linker = scrape_nlp.add_pipe("ann_linker", last=True)
ann_linker.set_kb(ann_kb)
scrape_nlp.add_pipe("textrank")
scrape_nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner',
#  'ann_linker',
#  'textrank']

# %%
doc = scrape_nlp(docs[1])

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">How Family that Runs Azerbaijan Built
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     an Empire of Hidden Wealth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .<br>On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October 31, 2003
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ilham Aliyev
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">1342265</a>
# </span>
# </mark>
# , the newly elected president of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Azerbaijan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">1551574</a>
# </span>
# </mark>
# , stood behind a podium and a profusion of white flowers to address presidents, prime ministers and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  other guests assembled at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Respublika Palace
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">388148</a>
# </span>
# </mark>
# .
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  touching the constitution and then the
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Koran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aliyev
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">1342265</a>
# </span>
# </mark>
#  swore to serve his people.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     That night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , fireworks lit up the sky of the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Azeri
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">388148</a>
# </span>
# </mark>
#  capital,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Baku
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aliyev
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">1342265</a>
# </span>
# </mark>
# ’s election to lead this energy-rich former
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Soviet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  republic bordering both
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Iran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  had been all but guaranteed. His ailing father,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Heydar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">246799</a>
# </span>
# </mark>
# , an ex-KGB officer, had served in the same role for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the previous 10 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Election monitors reported that police had beaten and detained political opponents, in line with the country’s reputation for repression.<br>Becoming president wasn’t
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aliyev
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON
#  <a style="text-decoration: none; color: inherit; font-weight: normal" href="#">1342265</a>
# </span>
# </mark>
# ’s only ascension during
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2003
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Using a network of secretive companies in offshore tax havens, his family, advisers and allies set about acquiring expensive overseas homes and positions in the country’s valuable industries and natural resources, including the family’s majority control of a major gold mine that has been unknown until now.<br>The new details of the
# <mark class="entity" style="backg

# %%
records = []
for phrase in doc._.phrases[:30]:
    record = (phrase.text, phrase.rank, phrase.count, set((ent.text, ent.kb_id_) for chunk in phrase.chunks for ent in chunk.ents))
    records.append((record[0], record[1], record[2], [{"text": e[0], "kb_id": e[1]} for e in record[-1]]))

# %%
import pandas as pd

# %%
raw_entities = pd.DataFrame.from_records(records, columns=["phrase", "rank", "count", "entities"]).explode("entities")
df = pd.concat(  # type: ignore
    [
        raw_entities.drop(columns="entities"),
        pd.json_normalize(raw_entities.entities).set_index(raw_entities.index),  # type: ignore
    ],
    axis=1,
)

# %%
df
# Out:
#                                                phrase      rank  count  \
# 0                   Azerbaijan President Ilham Aliyev  0.082795      2
# 0                   Azerbaijan President Ilham Aliyev  0.082795      2
# 1                                    President Aliyev  0.071555      1
# 2                               AtaHolding Azerbaijan  0.069281      2
# 3                                     Mossack Fonseca  0.069242     24
# 4                                          Azerbaijan  0.065796     25
# 4                                          Azerbaijan  0.065796     25
# 4                                          Azerbaijan  0.065796     25
# 4                                          Azerbaijan  0.065796     25
# 4                                          Azerbaijan  0.065796     25
# 4                                          Azerbaijan  0.065796     25
# 5                    Azerbaijan Richard D. Kauzlarich  0.060485      1
# 5                    Azerbaijan Richard D. Kauzlarich  0.060485      1
# 6                                  offshore companies  0.059752      2
# 7                                        Ilham Aliyev  0.059201      4
# 8                                       Heydar Aliyev  0.058310      1
# 9                                              Aliyev  0.057629     19
# 10                                      new companies  0.055708      1
# 11                                          companies  0.055239      1
# 12                                secretive companies  0.054224      1
# 13  Azeri investigative journalist Khadija Ismayilova  0.049191      1
# 13  Azeri investigative journalist Khadija Ismayilova  0.049191      1
# 14                          S. President Barack Obama  0.048902      2
# 15                         other former tax officials  0.048342      1
# 16                                      family friend  0.047675      1
# 17          Investigative reporter Khadija Ismayilova  0.045958      2
# 18                                           families  0.045955      1
# 19                              Londex Resources S.A.  0.045497      2
# 20                          President Aliyev’s family  0.045347      2
# 21                                   Londex Resources  0.044973      2
# 22                       President Aliyev’s daughters  0.043956      2
# 23                                offshore tax havens  0.043511      1
# 24             FM Management Holding Group S.A. Stand  0.043419      1
# 25                                 Khadija Ismayilova  0.042795      3
# 26                            Mossack Fonseca’s files  0.042529      2
# 27                          the Mossack Fonseca files  0.042529      1
# 28  the Azerbaijan International Mineral Resources...  0.041336      2
# 29                          Azerbaijan’s tax minister  0.041028      1
#
#                                                  text    kb_id
# 0                                        Ilham Aliyev  1342265
# 0                                          Azerbaijan   246799
# 1                                              Aliyev  1342265
# 2                               AtaHolding Azerbaijan   246799
# 3                                     Mossack Fonseca   388148
# 4                                          Azerbaijan   918573
# 4                                          Azerbaijan   442619
# 4                                          Azerbaijan   281073
# 4                                          Azerbaijan  1551574
# 4                                          Azerbaijan   246799
# 4                                          Azerbaijan  1470056
# 5                               Richard D. Kauzlarich
# 5                                          Azerbaijan   281073
# 6                                                 NaN      NaN
# 7                                        Ilham Aliyev  1342265
# 8                                       Heydar Aliyev   246799
# 9                                              Aliyev  1342265
# 10                                                NaN      NaN
# 11                                                NaN      NaN
# 12                                                NaN      NaN
# 13                                 Khadija Ismayilova
# 13                                              Azeri   388148
# 14                                       Barack Obama
# 15                                                NaN      NaN
# 16                                                NaN      NaN
# 17                                 Khadija Ismayilova
# 18                                                NaN      NaN
# 19                              Londex Resources S.A.
# 20                                             Aliyev  1342265
# 21                                   Londex Resources
# 22                                             Aliyev  1342265
# 23                                                NaN      NaN
# 24             FM Management Holding Group S.A. Stand   767041
# 25                                 Khadija Ismayilova
# 26                                    Mossack Fonseca   388148
# 27                                                NaN      NaN
# 28  the Azerbaijan International Mineral Resources...  1551574
# 29                                         Azerbaijan  1470056

# %%
entities_to_review = df.loc[lambda d: (d.text.notnull()) & (d.kb_id == '')]
entities_to_review
# Out:
#                                                phrase      rank  count  \
# 5                    Azerbaijan Richard D. Kauzlarich  0.060485      1
# 13  Azeri investigative journalist Khadija Ismayilova  0.049191      1
# 14                          S. President Barack Obama  0.048902      2
# 17          Investigative reporter Khadija Ismayilova  0.045958      2
# 19                              Londex Resources S.A.  0.045497      2
# 21                                   Londex Resources  0.044973      2
# 25                                 Khadija Ismayilova  0.042795      3
#
#                      text kb_id
# 5   Richard D. Kauzlarich
# 13     Khadija Ismayilova
# 14           Barack Obama
# 17     Khadija Ismayilova
# 19  Londex Resources S.A.
# 21       Londex Resources
# 25     Khadija Ismayilova

# %%
for_review: list[pd.DataFrame] = []
for doc in scrape_nlp.pipe(docs):
    records = []
    for phrase in doc._.phrases[:30]:
        records.append(
            (
                phrase.text,
                phrase.rank,
                phrase.count,
                [
                    {"text": text, "kb_id": kb_id}
                    for text, kb_id in set(
                        (ent.text, ent.kb_id_) for chunk in phrase.chunks for ent in chunk.ents
                    )
                ],
            )
        )
    raw_entities = pd.DataFrame.from_records(
        records, columns=["phrase", "rank", "count", "entities"]
    ).explode("entities")
    df = pd.concat(  # type: ignore
        [
            raw_entities.drop(columns="entities"),
            pd.json_normalize(raw_entities.entities).set_index(raw_entities.index),  # type: ignore
        ],
        axis=1,
    )
    entities_to_review = df.loc[lambda d: (d.text.notnull()) & (d.kb_id == "")]
    for_review.append(entities_to_review)

# %%
for_review
# Out:
# [                                        phrase      rank  count  \
#  0     Former Czech prime minister Andrej Babis  0.085349      1
#  3                  former Czech prime minister  0.071176      1
#  5                                    Czech law  0.061685      1
#  6                                         ICIJ  0.060946     11
#  7                                        Czech  0.058808      8
#  8   Former Czech leader’s secret French estate  0.057126      1
#  9        Hungarian Prime Minister Victor Orbán  0.056900      1
#  9        Hungarian Prime Minister Victor Orbán  0.056900      1
#  12          Freedom Party leader Herbert Kickl  0.050929      1
#  12          Freedom Party leader Herbert Kickl  0.050929      1
#  15                  ICIJ’s Czech media partner  0.050260      1
#  15                  ICIJ’s Czech media partner  0.050260      1
#  17                              Pandora Papers  0.049464      2
#  19                              Chateau Bigaud  0.047976      4
#  26                                   Last year  0.042743      1
#  29                               Freedom Party  0.041867      1
#
#                text kb_id
#  0            Czech
#  3            Czech
#  5            Czech
#  6             ICIJ
#  7            Czech
#  8            Czech
#  9        Hungarian
#  9     Victor Orbán
#  12   Herbert Kickl
#  12   Freedom Party
#  15            ICIJ
#  15           Czech
#  17  Pandora Papers
#  19  Chateau Bigaud
#  26       Last year
#  29   Freedom Party        ,
#                                                 phrase      rank  count  \
#  5                    Azerbaijan Richard D. Kauzlarich  0.060485      1
#  13  Azeri investigative journalist Khadija Ismayilova  0.049191      1
#  14                          S. President Barack Obama  0.048902      2
#  17          Investigative reporter Khadija Ismayilova  0.045958      2
#  19                              Londex Resources S.A.  0.045497      2
#  21                                   Londex Resources  0.044973      2
#  25                                 Khadija Ismayilova  0.042795      3
#
#                       text kb_id
#  5   Richard D. Kauzlarich
#  13     Khadija Ismayilova
#  14           Barack Obama
#  17     Khadija Ismayilova
#  19  Londex Resources S.A.
#  21       Londex Resources
#  25     Khadija Ismayilova        ]
